# %% [markdown]
# ### 배우 이름 크롤링

# %%
#라이브러리 불러오기 
# webdriver 웹 페이지를 '통제'하기 위한 라이브러리
from selenium import webdriver as wb 
from selenium.webdriver.common.by import By #by (태그정보를 알려줄때 )
from selenium.webdriver.common.keys import Keys
# Keys = 웹을 통해 값을 입력해 줄때 사용하는 라이브러리 == 컴퓨터용 키보드 
from bs4 import BeautifulSoup as bs

# %%
driver = wb.Chrome()
driver.get('https://brikorea.com/rk/drama2210')

# %%
actor = driver.find_elements(By.CSS_SELECTOR,'#wrapper > section > div > div.row > div:nth-child(5) > div > div.visible-xs > table > tbody  td.text-left.bold')

# %%
actor_list_10 = []
for i in range(len(actor)):
    actor_list_10.append(actor[i].text)
actor_list_10
# Out:
# ['김고은',
#  '이승기',
#  '이세영',
#  '위하준',
#  '남지현',
#  '육성재',
#  '박지후',
#  '정채연',
#  '엄지원',
#  '장승조',
#  '이종원',
#  '고경표',
#  '이하나',
#  '곽동연',
#  '지창욱',
#  '차예련',
#  '정일우',
#  '손현주',
#  '최대훈',
#  '김재영',
#  '남상지',
#  '김선아',
#  '강민아',
#  '이유미',
#  '연우',
#  '정문성',
#  '정우',
#  '김슬기',
#  '임주환',
#  '김효진',
#  '옥택연',
#  '이미숙',
#  '차민지',
#  '정은지',
#  '이현진',
#  '안재욱',
#  '임지연',
#  '김소은',
#  '이승연',
#  '고성희',
#  '윤균상',
#  '음문석',
#  '성동일',
#  '박세영',
#  '최원영',
#  '권율',
#  '이태성',
#  '김승수',
#  '강형석',
#  '배현성']

# %%
# Out:
# ['김고은',
#  '이승기',
#  '이세영',
#  '위하준',
#  '남지현',
#  '육성재',
#  '박지후',
#  '정채연',
#  '엄지원',
#  '장승조',
#  '이종원',
#  '고경표',
#  '이하나',
#  '곽동연',
#  '지창욱',
#  '차예련',
#  '정일우',
#  '손현주',
#  '최대훈',
#  '김재영',
#  '남상지',
#  '김선아',
#  '강민아',
#  '이유미',
#  '연우',
#  '정문성',
#  '정우',
#  '김슬기',
#  '임주환',
#  '김효진',
#  '옥택연',
#  '이미숙',
#  '차민지',
#  '정은지',
#  '이현진',
#  '안재욱',
#  '임지연',
#  '김소은',
#  '이승연',
#  '고성희',
#  '윤균상',
#  '음문석',
#  '성동일',
#  '박세영',
#  '최원영',
#  '권율',
#  '이태성',
#  '김승수',
#  '강형석',
#  '배현성']

# %%
driver = wb.Chrome()
driver.get('https://brikorea.com/rk/drama2209')

# %%
actor = driver.find_elements(By.CSS_SELECTOR,'#wrapper > section > div > div.row > div:nth-child(5) > div > div.visible-xs > table > tbody  td.text-left.bold')

# %%
actor_list_9 = []
for i in range(len(actor)):
    actor_list_9.append(actor[i].text)
actor_list_9
# Out:
# ['박은빈',
#  '이종석',
#  '강태오',
#  '정소민',
#  '이재욱',
#  '강기영',
#  '김세정',
#  '배다빈',
#  '윤시윤',
#  '장승조',
#  '김고은',
#  '차예련',
#  '서인국',
#  '신동미',
#  '임윤아',
#  '황민현',
#  '김주헌',
#  '손현주',
#  '지창욱',
#  '남지현',
#  '신승호',
#  '김향기',
#  '지성',
#  '오연서',
#  '김효진',
#  '박지후',
#  '정일우',
#  '전배수',
#  '이현진',
#  '이승연',
#  '서범준',
#  '남윤수',
#  '음문석',
#  '최대훈',
#  '서지혜',
#  '최다니엘',
#  '양경원',
#  '남상지',
#  '옥자연',
#  '권유리',
#  '최수영',
#  '이유리',
#  '이휘향',
#  '이수경',
#  '허성태',
#  '위하준',
#  '이경영',
#  '정문성',
#  '성동일',
#  '원지안']

# %%
driver = wb.Chrome()
driver.get('https://brikorea.com/rk/drama2207')

# %%
actor = driver.find_elements(By.CSS_SELECTOR,'#wrapper > section > div > div.row > div:nth-child(5) > div > div.visible-xs > table > tbody td.text-left.bold')

# %%
actor_list_7 = []
for i in range(len(actor)):
    actor_list_7.append(actor[i].text)
actor_list_7
# Out:
# ['박은빈',
#  '강태오',
#  '강기영',
#  '서현진',
#  '이재욱',
#  '정소민',
#  '이주빈',
#  '황인엽',
#  '박병은',
#  '허준호',
#  '서인국',
#  '소지섭',
#  '강하늘',
#  '배다빈',
#  '윤시윤',
#  '황민현',
#  '차예련',
#  '전소민',
#  '염정아',
#  '신동미',
#  '오연서',
#  '나인우',
#  '서현',
#  '오민석',
#  '신승호',
#  '전배수',
#  '이상엽',
#  '이유영',
#  '임수향',
#  '문가영',
#  '배인혁',
#  '이유리',
#  '이무생',
#  '여진구',
#  '신성록',
#  '이현진',
#  '김동욱',
#  '유선',
#  '남상지',
#  '서범준',
#  '이경영',
#  '김성규',
#  '김지영',
#  '곽시양',
#  '허성태',
#  '강영석',
#  '이휘향',
#  '채정안',
#  '유준상',
#  '권수현']

# %%
driver = wb.Chrome()
driver.get('https://brikorea.com/rk/drama2206')

# %%
actor = driver.find_elements(By.CSS_SELECTOR,'#wrapper > section > div > div.row > div:nth-child(5) > div > div.visible-xs > table > tbody td.text-left.bold ' )

# %%
actor_list_6 = []
for i in range(len(actor)):
    actor_list_6.append(actor[i].text)
actor_list_6
# Out:
# ['손석구',
#  '이병헌',
#  '신민아',
#  '이준기',
#  '이민기',
#  '임수향',
#  '한지민',
#  '이엘',
#  '정동원',
#  '강한나',
#  '서현진',
#  '박해진',
#  '이준',
#  '진기주',
#  '정준호',
#  '홍지윤',
#  '차승원',
#  '이성경',
#  '김지은',
#  '김지원',
#  '황인엽',
#  '이광수',
#  '이서진',
#  '성훈',
#  '이정은',
#  '소지섭',
#  '이경영',
#  '설현',
#  '박주현',
#  '장혁',
#  '홍은희',
#  '김영대',
#  '채종협',
#  '이승연',
#  '신동욱',
#  '곽도원',
#  '차예련',
#  '서지혜',
#  '박지연',
#  '윤두준',
#  '한고은',
#  '이경영',
#  '안보현',
#  '허성태',
#  '김광규',
#  '남상지',
#  '이주빈',
#  '배인혁',
#  '김우석',
#  '조보아']

# %%
actor_list_all = actor_list_10+actor_list_9+actor_list_7+actor_list_6

# %%
actor_list_all
# Out:
# ['김고은',
#  '이승기',
#  '이세영',
#  '위하준',
#  '남지현',
#  '육성재',
#  '박지후',
#  '정채연',
#  '엄지원',
#  '장승조',
#  '이종원',
#  '고경표',
#  '이하나',
#  '곽동연',
#  '지창욱',
#  '차예련',
#  '정일우',
#  '손현주',
#  '최대훈',
#  '김재영',
#  '남상지',
#  '김선아',
#  '강민아',
#  '이유미',
#  '연우',
#  '정문성',
#  '정우',
#  '김슬기',
#  '임주환',
#  '김효진',
#  '옥택연',
#  '이미숙',
#  '차민지',
#  '정은지',
#  '이현진',
#  '안재욱',
#  '임지연',
#  '김소은',
#  '이승연',
#  '고성희',
#  '윤균상',
#  '음문석',
#  '성동일',
#  '박세영',
#  '최원영',
#  '권율',
#  '이태성',
#  '김승수',
#  '강형석',
#  '배현성',
#  '박은빈',
#  '이종석',
#  '강태오',
#  '정소민',
#  '이재욱',
#  '강기영',
#  '김세정',
#  '배다빈',
#  '윤시윤',
#  '장승조',
#  '김고은',
#  '차예련',
#  '서인국',
#  '신동미',
#  '임윤아',
#  '황민현',
#  '김주헌',
#  '손현주',
#  '지창욱',
#  '남지현',
#  '신승호',
#  '김향기',
#  '지성',
#  '오연서',
#  '김효진',
#  '박지후',
#  '정일우',
#  '전배수',
#  '이현진',
#  '이승연',
#  '서범준',
#  '남윤수',
#  '음문석',
#  '최대훈',
#  '서지혜',
#  '최다니엘',
#  '양경원',
#  '남상지',
#  '옥자연',
#  '권유리',
#  '최수영',
#  '이유리',
#  '이휘향',
#  '이수경',
#  '허성태',
#  '위하준',
#  '이경영',
#  '정문성',
#  '성동일',
#  '원지안',
# ...

# %%
import pandas as pd

# %%
actor_number = []
for i in range(len(actor_list_all)):
   actor_number.append(i+1)

# %%
actor
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="b28a354426706bf4f620a4a696209d06", element="72b787a1-2cae-4529-a24c-e97adc3ca622")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b28a354426706bf4f620a4a696209d06", element="e9fbb8b4-574a-4a33-8f09-af76b9a887c0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b28a354426706bf4f620a4a696209d06", element="49c4a6ef-41eb-486f-8bac-ea1d234c6f0d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b28a354426706bf4f620a4a696209d06", element="62625431-77e0-4282-8a7e-43da3fe430b3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b28a354426706bf4f620a4a696209d06", element="5cb738e6-0bdb-46cd-a805-47ae3acc78cd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b28a354426706bf4f620a4a696209d06", element="545d4c46-3cbc-46bf-a958-de639d317caf")>,
# ...

# %%
dic = {'배우연번' : actor_number, '배우명' : actor_list_all}

# %%
df= pd.DataFrame(dic)
df.to_csv('배우명.csv', encoding ="EUC-KR")

# %%
actor_data = pd.read_csv('./배우컬럼.csv', encoding ="EUC-KR", index_col="배우연번")

# %%
actor_data.head()
# Out:
#       배우명  생년월일   나이   소속사   키, 몸무게  성별   배우 이미지1   배우 이미지2  배우 이미지3  배우 이미지4  \
# 배우연번
# 1     강기영    NaN  NaN   NaN     NaN  NaN       NaN      NaN      NaN      NaN
# 2     강민아    NaN  NaN   NaN     NaN  NaN       NaN      NaN      NaN      NaN
# 3     강영석    NaN  NaN   NaN     NaN  NaN       NaN      NaN      NaN      NaN
# 4     강주은    NaN  NaN   NaN     NaN  NaN       NaN      NaN      NaN      NaN
# 5     강태오    NaN  NaN   NaN     NaN  NaN       NaN      NaN      NaN      NaN
#
#       배우 이미지5  음색   목소리톤
# 배우연번
# 1         NaN  NaN   NaN
# 2         NaN  NaN   NaN
# 3         NaN  NaN   NaN
# 4         NaN  NaN   NaN
# 5         NaN  NaN   NaN

# %%
# 배우 프로필에 있는 정보 
all_list = []

# %%
import time

# %%
driver = wb.Chrome()
time.sleep(0.5)
for i in range(1,len(actor_data)+1):
    driver.get(f'https://search.naver.com/search.naver?sm=tab_hty.top&where=nexearch&query={actor_data["배우명"][i]}+프로필&oquery=1&tqi=hGICLdp0Jy0ssg38Hc0ssssstf0-517978')
    time.sleep(0.5)
    dd_list = driver.find_elements(By.CSS_SELECTOR,'#main_pack div.cm_content_wrap > div.cm_content_area._cm_content_area_profile > div > div.detail_info > div > dl dd')
    for j in range(0,len(dd_list)):
        actor_data.iloc[i-1,j+1]=dd_list[j].text 
        time.sleep(0.5)

# %%
actor_data
# Out:
#        배우명                             생년월일   \
# 배우연번
# 1      강기영                     Ki Young Kang
# 2      강민아                       에이치앤드엔터테인먼트
# 3      강영석            1991. 8. 12., 사자자리, 양띠
# 4      강주은                             1971.
# 5      강태오                          맨오브크리에이션
# 6      강하늘                               김하늘
# 7      강한나                              키이스트
# 8      강형석             1992. 1. 1., 염소자리, 양띠
# 9      고경표                             1990.
# 10     고두심  1951. 5. 22. 제주특별자치도, 쌍둥이자리, 토끼띠
# 11     고성희                       Sung Hee Ko
# 12     곽도원                          마다엔터테인먼트
# 13     곽동연                       에이치앤드엔터테인먼트
# 14     곽시양          1987. 1. 15., 염소자리, 호랑이띠
# 15     권수현          1986. 8. 18., 사자자리, 호랑이띠
# 16     권유리                  소녀시대, 소녀시대-Oh!GG
# 17      권율                     권세인, Yul Kwon
# 18    김강훈     2009. 6. 7. 충청북도 청주, 쌍둥이자리, 소띠
# 19      김건                               NaN
# 20     김고은              1991. 7. 2., 게자리, 양띠
# ...

# %%
actor_data.to_csv('배우프로필.csv', encoding ="EUC-KR")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Input In [478], in <cell line: 1>()
# ----> 1 actor_data.to_csv('배우프로필.csv', encoding ="EUC-KR")
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:3551, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3540 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3542 formatter = DataFrameFormatter(
#    3543     frame=df,
#    3544     header=header,
#    (...)
#    3548     decimal=decimal,
#    3549 )
# -> 3551 return DataFrameRenderer(formatter).to_csv(
#    3552     path_or_buf,
#    3553     line_terminator=line_terminator,
#    3554     sep=sep,
#    3555     encoding=encoding,
# ...

# %%
#main_pack > section.sc_new.cs_common_module.case_normal._au_people_content_wrap.color_17 > div.cm_content_wrap > div.cm_content_area._cm_content_area_profile > div > div.detail_info > div > dl > div:nth-child(1) > dd

# %%
#main_pack > section.sc_new.cs_common_module.case_normal._au_people_content_wrap.color_17 > div.cm_content_wrap > div.cm_content_area._cm_content_area_profile > div > div.detail_info > div > dl > div:nth-child(1) > dd

# %%
actor_data =pd.read_csv('./배우프로필.csv', index_col='배우연번', encoding ="EUC-KR")

# %%
actor_data
# Out:
#        배우명        생년월일   나이                   소속사       키  몸무게  성별  연령대 분류  \
# 배우연번
# 1      강기영   1983.10.14   40                 나무엑터스  178.0  70.0   남     성인
# 2      강민아   1997.03.20   26           에이치앤드엔터테인먼트  160.0   NaN   여     성인
# 3      강영석   1991.08.12   32               티에이치컴퍼니  181.0  69.0   남     성인
# 4      강주은   2006.03.22   17                   NaN  162.0   NaN   여     아역
# 5      강태오  1994.06.20    29              맨오브크리에이션  180.0   NaN   남     성인
# 6      강하늘   1990.02.21   33               티에이치컴퍼니  181.0  70.0   남     성인
# 7      강한나   1989.01.30   34                  키이스트  170.0   NaN   여     성인
# 8      강형석   1992.01.01   31             에이엠엔터테인먼트    NaN   NaN   남     성인
# 9      고경표   1990.06.11   33                씨엘엔컴퍼니  185.0  72.0   남     성인
# 10     고두심   1951.05.22   72            맥스파워엔터테인먼트  160.0  72.0   여     노년
# 11     고성희   1990.05.21   33            엠에스팀엔터테인먼트  170.0  48.0   여     성인
# ...

# %%
import os
from urllib.request import urlretrieve

# %%
driver = wb.Chrome()
time.sleep(0.5)  
img_list =[]
driver.get(f'https://search.naver.com/search.naver?where=image&sm=tab_jum&query=%EA%B0%95%EA%B8%B0%EC%98%81')
time.sleep(0.5)
soup=bs(driver.page_source, 'lxml')
act_img = soup.select('div.thumb > a > img')
img_list2 = [img['src'] for img in act_img ] # 이미지 주소 가져와서 리스트에 저장하는 코드
for img2 in img_list2:
    if img2[:4] != 'data': # data 라고 써진 것은 배제 하는 
        print(img2)
# Out:
# https://search.pstatic.net/common/?src=http%3A%2F%2Fblogfiles.naver.net%2FMjAyMjA4MjVfMTEz%2FMDAxNjYxMzk5NjIxOTk3.7CX9ojHOPggXVowPGOT87_LwoBr7hG3mgFHkmpF0I6cg.oBIMjw7E0pJLWeQR74wFiAyPqCwVZPGl3VmyXnj0aUQg.JPEG.ehtkakxh5%2FIMG_9600.JPG&type=a340
# https://search.pstatic.net/common/?src=http%3A%2F%2Fimgnews.naver.net%2Fimage%2F5348%2F2022%2F08%2F19%2F18_820731_83420_20220819092203945.jpg&type=a340
# https://search.pstatic.net/sunny/?src=https%3A%2F%2Fimage.ytn.co.kr%2Fgeneral%2Fjpg%2F2022%2F0808%2F202208081000183329_t.jpg&type=a340
# https://search.pstatic.net/common/?src=http%3A%2F%2Fblogfiles.naver.net%2FMjAyMjA4MjNfNjMg%2FMDAxNjYxMjQ0NjIyMDk0.gbscoOEj2g4ttdHpQVsVsTlDupZp2BX47hJQHhf-Dyog.cZR9QGV6xMXOl_-vJts9UOBpbr6XQthdwCksl_sNTlEg.PNG.masterpark2010%2F4-2.png&type=a340
# https://search.pstatic.net/common/?src=http%3A%2F%2Fimgnews.naver.net%2Fimage%2F047%2F2019%2F07%2F22%2F0002234331_001_20190722145311060.jpg&type=a340
# ...

# %%
img_list2
urlretrieve(img_list[-1], f'C:/Users/smhrd/Final Data/배우이미지/{actor_data["배우명"][a]}'+str(a+1)+'.jpg')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [374], in <cell line: 2>()
#       1 img_list2
# ----> 2 urlretrieve(img_list[-1], f'C:/Users/smhrd/Final Data/배우이미지/{actor_data["배우명"][a]}'+str(a+1)+'.jpg')
#
# IndexError: list index out of range

# %%
len(actor_data)
actor_data["배우명"][200]
# Out:
# '황인엽'

# %%
driver = wb.Chrome()
time.sleep(0.5)  
for c in range(1, len(actor_data)+1):
    if not os.path.isdir(f'C:/Users/smhrd/Final Data/배우이미지/{actor_data["배우명"][c]}'):
        os.mkdir(f'C:/Users/smhrd/Final Data/배우이미지/{actor_data["배우명"][c]}')
        print("폴더생성 완료입니다.")
    else:
        print("이미 있는 폴더입니다")
    
for i in range(1,len(actor_data)+1):  
    driver.get(f'https://search.naver.com/search.naver?where=image&sm=tab_jum&query={actor_data["배우명"][i]}')
    time.sleep(0.5)
    img_list2=[]
    img_list3=[]
    img_list4=[]
    soup=bs(driver.page_source, 'lxml')
    act_img = soup.select('div.thumb > a > img')
    img_list2 = [img['src'] for img in act_img ]
    for a in range(0,5):
        for img2 in img_list2:
            if img2[:4] != 'data':
                img_list3.append(img2)
                img_list4=img_list3[0:5]
                actor_data.iloc[i-1,a+8]=img_list4[a] 
                urlretrieve(img_list4[a], f'C:/Users/smhrd/Final Data/배우이미지/{actor_data["배우명"][i]}/{actor_data["배우명"][i]}'+str(a+1)+'.jpg')
# Out:
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# 이미 있는 폴더입니다
# ...

# %%
actor_data =pd.read_csv('./배우프로필사진추가.csv', encoding ="EUC-KR")

# %%
actor_data
# Out:
#      배우연번   배우명        생년월일   나이                   소속사       키  몸무게  성별   \
# 0       1   강기영   1983.10.14   40                 나무엑터스  178.0  70.0   남
# 1       2   강민아   1997.03.20   26           에이치앤드엔터테인먼트  160.0   NaN   여
# 2       3   강영석   1991.08.12   32               티에이치컴퍼니  181.0  69.0   남
# 3       4   강주은   2006.03.22   17                   NaN  162.0   NaN   여
# 4       5   강태오  1994.06.20    29              맨오브크리에이션  180.0   NaN   남
# 5       6   강하늘   1990.02.21   33               티에이치컴퍼니  181.0  70.0   남
# 6       7   강한나   1989.01.30   34                  키이스트  170.0   NaN   여
# 7       8   강형석   1992.01.01   31             에이엠엔터테인먼트    NaN   NaN   남
# 8       9   고경표   1990.06.11   33                씨엘엔컴퍼니  185.0  72.0   남
# 9      10   고두심   1951.05.22   72            맥스파워엔터테인먼트  160.0  72.0   여
# 10     11   고성희   1990.05.21   33            엠에스팀엔터테인먼트  170.0  48.0   여
# 11     12   곽도원   1973.05.17   50              마다엔터테인먼트  177.0   NaN   남
# ...

# %%
driver = wb.Chrome()
a=0
b=1
for i in range(3,7):
    driver.get(f'https://search.naver.com/search.naver?sm=tab_hty.top&where=nexearch&query={actor_data["배우명"][i]}+작품활동&oquery=1&tqi=hGICLdp0Jy0ssg38Hc0ssssstf0-517978')
    time.sleep(0.5)
    broadcast_tab = driver.find_elements(By.CSS_SELECTOR, '#main_pack div.cm_content_wrap > div > div > div.lego_scroll_date.type_less.font_black._tab_wrap > div.type_scroll._scroll > div > div > ul a')
    
    
    
    
    for d in range(0,2):
        next_page = driver.find_element(By.CSS_SELECTOR,'#main_pack  div.cm_content_wrap > div > div > div._tab_content._tab_area_onair > div.cm_paging_area.no_margin > div > a.pg_next.on')
        if d>=1:
            next_page.click()
            time.sleep(0.5)
        for c in range(0,6): 
            if broadcast_tab[a].text[0:2]=='방송':
                broadcast_tab[a].click()
                drama_title = driver.find_elements(By.CSS_SELECTOR, '#mflick > div:nth-child(1) > div  div > div > div.title.multi_line > div > strong > a')    
                if len(drama_title[c].text)!=0:
                    drama_title[c].click()
                    time.sleep(0.5)
                    driver.back()
                    broadcast_tab = driver.find_elements(By.CSS_SELECTOR, '#main_pack div.cm_content_wrap > div > div > div.lego_scroll_date.type_less.font_black._tab_wrap > div.type_scroll._scroll > div > div > ul a')  
                    broadcast_tab[a].click()
                    time.sleep(2)
            else:
                broadcast_tab[b].click()
                drama_title = driver.find_elements(By.CSS_SELECTOR, '#mflick > div:nth-child(1) > div  div > div > div.title.multi_line > div > strong > a')    
                if len(drama_title[c].text)!=0:
                    drama_title[c].click()
                    time.sleep(0.5)
                    driver.back()
                    broadcast_tab = driver.find_elements(By.CSS_SELECTOR, '#main_pack div.cm_content_wrap > div > div > div.lego_scroll_date.type_less.font_black._tab_wrap > div.type_scroll._scroll > div > div > ul a')    
                    broadcast_tab[b].click()
                    time.sleep(2)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Input In [878], in <cell line: 4>()
#       7 broadcast_tab = driver.find_elements(By.CSS_SELECTOR, '#main_pack div.cm_content_wrap > div > div > div.lego_scroll_date.type_less.font_black._tab_wrap > div.type_scroll._scroll > div > div > ul a')
#      12 for d in range(0,3):
# ---> 13     next_page = driver.find_element(By.CSS_SELECTOR,'#main_pack  div.cm_content_wrap > div > div > div._tab_content._tab_area_onair > div.cm_paging_area.no_margin > div > a.pg_next.on')
#      14     if d>=1:
#      15         next_page.click()
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:855, in WebDriver.find_element(self, by, value)
#     852     by = By.CSS_SELECTOR
#     853     value = '[name="%s"]' % value
# --> 855 return self.execute(Command.FIND_ELEMENT, {
#     856     'using': by,
# ...

# %%
next_page
# Out:
# []

# %%
drama_title[0].text
# Out:
# '틱톡 스테이지 커넥트: 스윗태오(TikTok Stage Connect: SweeTaeOh)'

# %%
for b in range(0,4):
        drama_title = driver.find_elements(By.CSS_SELECTOR, '#mflick > div:nth-child(1) > div  div > div > div.title.multi_line > div > strong > a')
        if len(drama_title[b].text)>0:
            drama_title[b].click()
            driver.back()
